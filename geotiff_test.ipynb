# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
im = Image.open("data_tif/train_5.tif")

# %%
for id in im.tag:
    print("{} : {}".format(id, im.tag[id]))
# Out:
# 256 : (256,)
# 257 : (256,)
# 258 : (16, 16, 16, 16)
# 259 : (1,)
# 262 : (2,)
# 270 : ('{"shape": [256, 256, 4]}',)
# 273 : (304,)
# 338 : (1,)
# 339 : (1,)
# 277 : (4,)
# 278 : (256,)
# 279 : (524288,)
# 284 : (1,)
# 305 : ('tifffile.py',)
# 306 : ('2017:04:26 23:11:27',)
# 254 : (0,)

# %%
im_array = np.array(im)

# %%
plt.imshow(im_array[:,:,3])
plt.show()

# %%
print(im_array[:,:,3])
# Out:
# [[28 27 27 ... 28 28 28]
#  [28 27 27 ... 28 28 28]
#  [27 27 27 ... 28 28 28]
#  ...
#  [26 26 26 ... 29 29 29]
#  [26 26 26 ... 29 29 28]
#  [26 26 26 ... 29 29 28]]
